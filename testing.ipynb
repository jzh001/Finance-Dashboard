# %%
import numpy as np
import pandas as pd
import finance_data_scraper as scraper
import dashboard as dash
import altair as alt

# %%
data = scraper.getYahooHistorical("AAPL", "1y")
data
# Out:
#            date        open        high         low       close     volume  \
# 0    2022-06-07  144.350006  149.000000  144.100006  148.710007   67808200
# 1    2022-06-08  148.580002  149.869995  147.460007  147.960007   53950200
# 2    2022-06-09  147.080002  147.949997  142.529999  142.639999   69473000
# 3    2022-06-10  140.279999  140.759995  137.059998  137.130005   91437900
# 4    2022-06-13  132.869995  135.199997  131.440002  131.880005  122207100
# ..          ...         ...         ...         ...         ...        ...
# 246  2023-05-31  177.330002  179.350006  176.759995  177.250000   99625300
# 247  2023-06-01  177.699997  180.119995  176.929993  180.089996   68901800
# 248  2023-06-02  181.029999  181.779999  179.259995  180.949997   61945900
# 249  2023-06-05  182.630005  184.949997  178.039993  179.580002  121946500
# 250  2023-06-06  179.970001  180.119995  177.429993  179.210007   64786500
#
#        adjclose  dividends
# 0    147.827286        0.0
# ...

# %%
def getResistSupportChart(df):
    x = np.arange(len(df))
    y = df['close'].values

    regression = np.polyfit(x, y, deg=1)
    print(regression)
    resistance_slope = regression[0]
    resistance_intercept = regression[1]
    support_slope = -resistance_slope
    support_intercept = resistance_intercept
    base_chart = alt.Chart(df.reset_index()).encode(
        x="date:T",
        y="close:Q",
    ).properties(height=350)

    price_line = base_chart.mark_line().encode(
        tooltip=["date:T", "close:Q"],
    )

    resistance_line = base_chart.transform_regression('x', 'y', method='linear', params=True).mark_line(color='red').encode(
        x='date:T',
        y=alt.Y('resistance_y', axis=alt.Axis(title='Price')),
    ).transform_calculate(
        resistance_y=f"x * {resistance_slope} + {resistance_intercept}"
    )

    support_line = base_chart.transform_regression('x', 'y', method='linear', params=True).mark_line(color='green').encode(
        x='date:T',
        y=alt.Y('support_y', axis=alt.Axis(title='Price')),
    ).transform_calculate(
        support_y=f"x * {support_slope} + {support_intercept}"
    )

    chart = (price_line + resistance_line + support_line).interactive()
    return chart

# %%
getResistSupportChart(data)
# Out:
# [6.95967757e-02 1.43468251e+02]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\jzheng\AppData\Local\Programs\Python\Python38\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     372         copy = self.copy(deep=False)
#     373         original_data = getattr(copy, "data", Undefined)
# --> 374         copy.data = _prepare_data(original_data, context)
#     375
#     376         if original_data is not Undefined:
#
# c:\Users\jzheng\AppData\Local\Programs\Python\Python38\lib\site-packages\altair\vegalite\v4\api.py in _prepare_data(data, context)
#      95     # consolidate inline data to top-level datasets
#      96     if context is not None and data_transformers.consolidate_datasets:
# ---> 97         data = _consolidate_data(data, context)
#      98
#      99     # if data is still not a recognized type, then return
#
# ...
